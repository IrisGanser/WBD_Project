# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
path = "/home/administrator/Documents/Web-based-data/Project/MobilePhoneData/"
SET3_M01 = pd.read_csv(path + "SET3/SET3_M01.CSV", header = None, names = ["user_id", "timestamp", "arrondissement_id"])

# %%
SET3_M01.head()
# Out:
#    user_id            timestamp  arrondissement_id
# 0    37509  2013-01-29 15:00:00                  3
# 1    84009  2013-01-14 07:00:00                  3
# 2    84009  2013-01-14 07:00:00                  3
# 3    84009  2013-01-14 07:00:00                  3
# 4    80150  2013-01-27 16:50:00                  3

# %%
# Out:
#           user_id            timestamp  arrondissement_id
# 43034434    52339  2013-01-07 01:30:00                 48
# 43034435    83848  2013-01-09 21:30:00                 48
# 43034436   148803  2013-01-17 12:00:00                 48
# 43034437    83848  2013-01-11 20:40:00                 48
# 43034438    83848  2013-01-11 20:50:00                 48

# %%
SET3_M01.shape
# Out:
# (43034439, 3)

# %%
n_user = len(SET3_M01.user_id.unique())
n_user
# Out:
# 146352

# %%
most_active_users = SET3_M01.user_id.value_counts()[:100]
most_active_users.index
# Out:
# Int64Index([ 29741, 115669, 145890, 145762, 101780,  92583,  28765,  87604,
#             101855, 107792, 127730,  92240,  13891,  86115,  48980, 101701,
#              91665,  87173,  25832,  78849,  41280,  81833, 148777,  33108,
#             115364, 127341, 129963,  27595,  71657,  45993,  29689, 128839,
#             111876,  43849, 112159,  17970,  12429,  68908,  74900,   6037,
#             124270,  67670,  35618,  87609,  88454,  77536,  26169, 115710,
#             119082,  57297, 122007,  51935,  94584, 139337,  79808,  84043,
#              85262, 117044,  12960,  75593, 117855, 114672, 127979, 123940,
#              56885,   8969,   1325, 100780,  96290,  50040, 103869,  50323,
#              10572,  87460,  31722,  17247,   5898,  45608,  70530, 133630,
#             127150,  26662,  79964, 117018,  58676, 124386, 116262,   6011,
#              25782,  96096,  52888,  28202,  26199, 115924,  92697,  37231,
#              65478,  47767, 136231,  13342],
# ...

# %%
arrondissements = pd.read_csv(path + "ContextData/SENEGAL_ARR.csv")

# %%
arrondissements.head()
# Out:
#    ARR_ID    REG        DEPT                  ARR
# 0       1  DAKAR       DAKAR  PARCELLES ASSAINIES
# 1       2  DAKAR       DAKAR             ALMADIES
# 2       3  DAKAR       DAKAR          GRAND DAKAR
# 3       4  DAKAR       DAKAR        DAKAR PLATEAU
# 4       5  DAKAR  GUEDIAWAYE           GUEDIAWAYE

# %%
arrondissements.REG.unique()
# Out:
# array(['DAKAR', 'THIES', 'DIOURBEL', 'FATICK', 'LOUGA', 'KAOLACK',
#        'KAFFRINE', 'SAINT-LOUIS', 'KOLDA', 'SEDHIOU', 'ZIGUINCHOR',
#        'KEDOUGOU', 'TAMBACOUNDA', 'MATAM'], dtype=object)

# %%
import shapefile

# %%
shape_senegal = shapefile.Reader(path + "ContextData/Shapefile_Senegal/senegal_arr_2014_wgs.shp")
print(shape_senegal)
# Out:
# shapefile Reader
#     123 shapes (type 'POLYGON')
#     123 records (5 fields)

# %%
len(shape_senegal.shapes())
# Out:
# 123

# %%
plt.figure()
for shape in shape_senegal.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x, y, color = "black", lw = 0.5)
    
#plt.savefig('test.png')

# %%
import geopandas
import descartes
map_senegal = geopandas.read_file(path + "ContextData/Shapefile_Senegal/senegal_arr_2014_wgs.shp")

# %%
map_senegal.info()
map_senegal.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 5 columns):
# ARR_ID      123 non-null int64
# REG         123 non-null object
# DEPT        123 non-null object
# ARR         123 non-null object
# geometry    123 non-null geometry
# dtypes: geometry(1), int64(1), object(3)
# memory usage: 4.9+ KB
#    ARR_ID    REG        DEPT                  ARR  \
# 0       1  DAKAR       DAKAR  PARCELLES ASSAINIES
# 1       2  DAKAR       DAKAR             ALMADIES
# 2       3  DAKAR       DAKAR          GRAND DAKAR
# 3       4  DAKAR       DAKAR        DAKAR PLATEAU
# 4       5  DAKAR  GUEDIAWAYE           GUEDIAWAYE
#
#                                             geometry
# 0  POLYGON ((-17.42284 14.76764, -17.42329 14.767...
# 1  MULTIPOLYGON (((-17.51195 14.75673, -17.51161 ...
# 2  POLYGON ((-17.42018 14.73348, -17.42003 14.733...
# 3  MULTIPOLYGON (((-17.43267 14.64669, -17.43276 ...
# ...

# %%
map_senegal.plot(cmap = 'jet', alpha = 0.6, column = "REG", figsize = (10, 10), edgecolor='grey')

# %%
map_senegal['area'] = map_senegal.area

# %%
mal_inc = pd.read_csv("/home/administrator/Documents/Web-based-data/Project/MalariaIncidence/INCIDENCE_RATE-per1000.csv")
mal_inc = mal_inc[mal_inc.year == 2013]
mal_inc = mal_inc.filter(['admin_unit', 'mean_value'])
mal_inc = mal_inc.rename(columns = {"admin_unit": "REG", "mean_value": "inc_rate"})

print(mal_inc)
# Out:
#             REG    inc_rate
# 0         Dakar   60.298439
# 2      Diourbel   39.331244
# 4        Fatick   43.484102
# 6      Kaffrine   38.200650
# 8       Kaolack   37.719223
# 10     Kedougou  139.921531
# 12        Kolda  119.758282
# 14        Louga   39.091685
# 16        Matam   50.528903
# 18  Saint-Louis   39.219976
# 20      Sedhiou   56.501624
# 22      Senegal   54.243962
# 24  Tambacounda   97.117335
# 26        Thies   41.947315
# 28   Ziguinchor   63.304454

# %%
map_senegal['inc_rate'] = 0.0

# %%
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'DAKAR'] = 60.298439
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'DIOURBEL'] = 39.331244
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'FATICK'] = 43.484102
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'KAFFRINE'] = 38.200650
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'KAOLACK'] = 37.719223
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'KEDOUGOU'] = 139.921531
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'KOLDA'] = 119.758282
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'LOUGA'] = 39.091685
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'MATAM'] = 50.528903
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'SAINT-LOUIS'] = 39.219976
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'SEDHIOU'] = 56.501624
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'TAMBACOUNDA'] = 97.117335
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'THIES'] = 41.947315
map_senegal['inc_rate'].loc[map_senegal['REG'] == 'ZIGUINCHOR'] = 63.304454
# Out:
# /home/administrator/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#for region in map_senegal.REG:
    #map_senegal['inc_rate'].loc[map_senegal['inc_rate'] == region] = mal_inc.inc_rate[mal_inc.REG == region.capitalize()]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(figsize = (12, 12))
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", size="5%", pad=0.5)

map_senegal.plot(column='inc_rate', ax=ax, legend=True,
                 cmap = 'viridis_r', edgecolor='grey', cax = cax,
                 legend_kwds={'label': "Malaria incidence rate per 1000", 'orientation': "horizontal"})
plt.title("Malaria incidence rate in Senegal in 2013", fontsize=16)
# Out:
# Text(0.5, 1, 'Malaria incidence rate in Senegal in 2013')

# %%
map_senegal['coords'] = map_senegal['geometry'].apply(lambda x: x.representative_point().coords[:])
map_senegal['coords'] = [coords[0] for coords in map_senegal['coords']]

# %%
#map_senegal['centroid'] = map_senegal['geometry'].centroid
#map_senegal['centroid'] = [centroid[0] for centroid in map_senegal['centroid']]

# %%
map_senegal.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 9 columns):
# ARR_ID      123 non-null int64
# REG         123 non-null object
# DEPT        123 non-null object
# ARR         123 non-null object
# geometry    123 non-null geometry
# area        123 non-null float64
# inc_rate    123 non-null float64
# coords      123 non-null object
# centroid    123 non-null geometry
# dtypes: float64(2), geometry(2), int64(1), object(4)
# memory usage: 8.7+ KB

# %%
fig, ax = plt.subplots(figsize = (15, 15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", size="5%", pad=0.5)

p = map_senegal.plot(column='inc_rate', ax=ax, legend=True,
                 cmap = 'viridis_r', edgecolor='grey', cax = cax,
                 legend_kwds={'label': "Malaria incidence rate per 1000", 'orientation': "horizontal"})

map_senegal.apply(lambda x: p.annotate(s=x.ARR_ID, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)
plt.title("Malaria incidence rate in Senegal in 2013", fontsize=16)
# Out:
# Text(0.5, 1, 'Malaria incidence rate in Senegal in 2013')

# %%
SE_ind = pd.read_csv("/home/administrator/Documents/Web-based-data/Project/SECovariates/social_ind.csv")
SE_ind['REG'] = SE_ind.region.str.upper()

    
SE_ind.head()
# Out:
#         region  literacy_rate  schooling_rate  poverty_rate          REG
# 0        Dakar           68.6            64.3          26.1        DAKAR
# 1     Diourbel           35.1            28.9          47.8     DIOURBEL
# 2  Tambacounda           35.0            44.6          62.5  TAMBACOUNDA
# 3  Saint-Louis           53.2            57.4          39.7  SAINT-LOUIS
# 4        Thies           53.8            53.4          41.3        THIES

# %%
SE_ind['lit_q'] = pd.qcut(SE_ind['literacy_rate'], 4, labels = [4, 3, 2, 1])
SE_ind['school_q'] = pd.qcut(SE_ind['schooling_rate'], 4, labels = [4, 3, 2, 1])
SE_ind['poverty_q'] = pd.qcut(SE_ind['poverty_rate'], 4, labels = [1, 2, 3, 4])
SE_ind
# Out:
#          region  literacy_rate  schooling_rate  poverty_rate          REG  \
# 0         Dakar           68.6            64.3          26.1        DAKAR
# 1      Diourbel           35.1            28.9          47.8     DIOURBEL
# 2   Tambacounda           35.0            44.6          62.5  TAMBACOUNDA
# 3   Saint-Louis           53.2            57.4          39.7  SAINT-LOUIS
# 4         Thies           53.8            53.4          41.3        THIES
# 5        Fatick           45.8            61.1          67.8       FATICK
# 6      Kaffrine           42.0            26.7          63.8     KAFFRINE
# 7       Kaolack           50.2            46.4          61.7      KAOLACK
# 8      Kedougou           35.0            63.2          71.3     KEDOUGOU
# 9         Kolda           43.7            51.9          76.6        KOLDA
# 10        Louga           36.4            30.3          26.8        LOUGA
# 11        Matam           28.4            42.1          45.2        MATAM
# ...

# %%
other_SE_ind = pd.read_csv("/home/administrator/Documents/Web-based-data/Project/SECovariates/SE_other_indicators.csv")
other_SE_ind = other_SE_ind.filter(['location', 'indicator', 'Value'])
other_SE_ind.head()
# Out:
#   location                                        indicator  Value
# 0    Dakar    Infant Mortality of children under five years   45.8
# 1    Dakar  Juvenile Mortality of children under five years   16.7
# 2    Dakar                         Life expectancy at birth   69.6
# 3    Dakar                                              hut   35.7
# 4    Dakar                                            booth   25.9

# %%
other_SE_ind = other_SE_ind.pivot_table(index = 'location', columns = 'indicator', values = 'Value')

# %%
other_SE_ind['REG'] = other_SE_ind.index.str.upper()
other_SE_ind.head()
# Out:
# indicator  Apartment building  Electricity  \
# location
# Dakar                     8.0         93.8
# Diourbel                  4.6         50.6
# Fatick                    5.8         27.4
# Kaffrine                  4.7         13.8
# Kaolack                   5.8         40.0
#
# indicator  Infant Mortality of children under five years  \
# location
# Dakar                                               45.8
# Diourbel                                            67.8
# Fatick                                              52.4
# Kaffrine                                            59.4
# Kaolack                                             57.5
#
# indicator  Juvenile Mortality of children under five years  \
# location
# Dakar                                                 16.7
# Diourbel                                              32.2
# Fatick                                                22.3
# Kaffrine                                              31.4
# ...

# %%
all_SE_ind = other_SE_ind.merge(SE_ind, on = 'REG')

# %%
all_SE_ind = all_SE_ind.drop(['region', 'Apartment building', 'Other Accommodations', 'Storey house'], 1)

# %%
print(all_SE_ind.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 12
# Data columns (total 17 columns):
# Electricity                                        13 non-null float64
# Infant Mortality of children under five years      13 non-null float64
# Juvenile Mortality of children under five years    13 non-null float64
# Life expectancy at birth                           13 non-null float64
# Total Population                                   13 non-null float64
# booth                                              13 non-null float64
# candle                                             13 non-null float64
# hut                                                13 non-null float64
# low house                                          13 non-null float64
# wood                                               13 non-null float64
# REG                                                13 non-null object
# literacy_rate                                      13 non-null float64
# ...

# %%
map_ind_sen = map_senegal.merge(all_SE_ind, on = 'REG', how = 'outer')

# %%
map_ind_sen.head()
# Out:
#    ARR_ID    REG        DEPT                  ARR  \
# 0       1  DAKAR       DAKAR  PARCELLES ASSAINIES
# 1       2  DAKAR       DAKAR             ALMADIES
# 2       3  DAKAR       DAKAR          GRAND DAKAR
# 3       4  DAKAR       DAKAR        DAKAR PLATEAU
# 4       5  DAKAR  GUEDIAWAYE           GUEDIAWAYE
#
#                                             geometry   inc_rate  \
# 0  POLYGON ((-17.42284 14.76764, -17.42329 14.767...  60.298439
# 1  MULTIPOLYGON (((-17.51195 14.75673, -17.51161 ...  60.298439
# 2  POLYGON ((-17.42018 14.73348, -17.42003 14.733...  60.298439
# 3  MULTIPOLYGON (((-17.43267 14.64669, -17.43276 ...  60.298439
# 4  POLYGON ((-17.36185 14.79812, -17.35965 14.793...  60.298439
#
#                                       coords  Electricity  \
# 0   (-17.44249743592356, 14.750501149818676)         93.8
# 1  (-17.491730821356356, 14.732235066948933)         93.8
# 2  (-17.446755032138725, 14.712288180561526)         93.8
# ...

# %%
map_ind_sen = map_ind_sen.rename(columns = {"Infant Mortality of children under five years": "mort_infant", 
                                            "Juvenile Mortality of children under five years": "mort_juvenile"})

# %%
fig, ax = plt.subplots(figsize = (15, 15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", size="5%", pad=0.5)

p = map_ind_sen.plot(column='mort_infant', ax=ax, legend=True,
                 cmap = 'viridis_r', edgecolor='grey', cax = cax,
                 legend_kwds={'label': "Infant mortality rate per 1000", 'orientation': "horizontal"})
plt.title("Infant mortality rate in Senegal in 2013", fontsize=16)
# Out:
# /home/administrator/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:479: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Text(0.5, 1, 'Infant mortality rate in Senegal in 2013')

# %%
cities = pd.read_csv("/home/administrator/Documents/Web-based-data/Project/EcologicalCovariates/cities.csv")
cities.head()
# Out:
#              city        lat        lon
# 0           Dakar  14.693425 -17.447938
# 1  Touba, Senegal  14.864559 -15.876047
# 2           Thies  14.794809 -16.952927
# 3        Rufisque  14.716417 -17.273844
# 4         Kaolack  13.963176 -15.788883

# %%
cities_geom = geopandas.GeoDataFrame(cities, geometry=geopandas.points_from_xy(cities.lon, cities.lat))
cities_geom.head()
# Out:
#              city        lat        lon                    geometry
# 0           Dakar  14.693425 -17.447938  POINT (-17.44794 14.69342)
# 1  Touba, Senegal  14.864559 -15.876047  POINT (-15.87605 14.86456)
# 2           Thies  14.794809 -16.952927  POINT (-16.95293 14.79481)
# 3        Rufisque  14.716417 -17.273844  POINT (-17.27384 14.71642)
# 4         Kaolack  13.963176 -15.788883  POINT (-15.78888 13.96318)

# %%
fig, ax = plt.subplots(figsize = (15, 15))
ax.set_aspect('equal')
map_ind_sen.plot(ax = ax, color='white', edgecolor='grey')
cities_geom.plot(ax = ax, marker='o', color='red', markersize=10)

# %%
# Voronoi tesselation with cities
from scipy.spatial import Voronoi
from geovoronoi import voronoi_regions_from_coords

# %%
coords = [cities.lon, cities.lat]
print(coords)
# Out:
# [0    -17.447938
# 1    -15.876047
# 2    -16.952927
# 3    -17.273844
# 4    -15.788883
# 5    -16.965712
# 6    -16.403930
# 7    -15.295431
# 8    -16.051174
# 9    -15.344183
# 10   -13.089176
# 11   -15.688449
# 12   -14.418147
# 13   -15.906661
# 14   -16.812868
# 15   -16.823450
# 16   -15.024736
# 17   -16.505217
# 18   -16.228970
# 19   -16.402402
# 20   -15.884747
# 21   -16.449262
# 22   -13.552922
# 23   -15.553303
# 24   -17.136807
# 25   -12.286756
# 26   -17.119312
# 27   -17.059435
# 28   -16.632682
# 29   -13.924009
# 30   -13.321103
# 31   -15.774751
# 32   -16.442978
# 33   -14.803538
# 34   -13.571322
# 35   -12.456807
# 36   -16.881218
# 37   -15.115351
# 38   -16.372533
# 39   -15.876362
# 40   -16.705613
# 41   -14.647498
# 42   -16.152514
# 43   -15.573988
# 44   -13.175678
# Name: lon, dtype: float64, 0     14.693425
# 1     14.864559
# 2     14.794809
# 3     14.716417
# 4     13.963176
# 5     14.411794
# 6     12.753980
# 7     16.187637
# 8     14.704390
# ...

# %%
from scipy.spatial import Voronoi
from voronoi_helper import voronoi_finite_polygons_2d

# %%
#vor = Voronoi(cities[["lon", "lat"]].values)
#regions, vertices = voronoi_finite_polygons_2d(vor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-abd101f3c06a> in <module>
#       1 vor = Voronoi(cities[["lon", "lat"]].values)
# ----> 2 regions, vertices = voronoi_finite_polygons_2d(vor)
#
# NameError: name 'voronoi_finite_polygons_2d' is not defined

# %%
import bandicoot as bc
import statistics

# %%
SET3_M01.head()
# Out:
#    user_id           timestamp  arrondissement_id       date
# 0    37509 2013-01-29 15:00:00                  3 2013-01-29
# 1    84009 2013-01-14 07:00:00                  3 2013-01-14
# 2    84009 2013-01-14 07:00:00                  3 2013-01-14
# 3    84009 2013-01-14 07:00:00                  3 2013-01-14
# 4    80150 2013-01-27 16:50:00                  3 2013-01-27

# %%
SET3_M01['timestamp'] = pd.to_datetime(SET3_M01['timestamp'])

# %%
SET3_M01['date'] = SET3_M01['timestamp'].dt.normalize()

# %%
#pref_arr = SET3_M01.groupby(['user_id', 'date'])['arrondissement_id'].agg(lambda x: pd.Series.mode(x)[0])

# %%
#pref_arr.to_csv("/home/administrator/Documents/Web-based-data/Project/MobilePhoneData/SET3/MO1_pref_arr.csv")
# Out:
# /home/administrator/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
pref_arr_df = pd.read_csv("/home/administrator/Documents/Web-based-data/Project/MobilePhoneData/SET3/MO1_pref_arr.csv", 
                       header = None, names = ["user_id", "date", "pref_arr"])

# %%
pref_arr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4023935 entries, 0 to 4023934
# Data columns (total 3 columns):
# user_id     int64
# date        object
# pref_arr    int64
# dtypes: int64(2), object(1)
# memory usage: 92.1+ MB

# %%
pref_arr_df.head()
# Out:
#    user_id        date  pref_arr
# 0        1  2013-01-01         1
# 1        1  2013-01-02         4
# 2        1  2013-01-03         1
# 3        1  2013-01-04         4
# 4        1  2013-01-05         1

# %%
pref_arr_geom = pref_arr_df.merge(map_senegal, left_on = "pref_arr", right_on = "ARR_ID")
pref_arr_geom = geopandas.GeoDataFrame(pref_arr_geom, geometry = "geometry")

# %%
pref_arr_geom.head()

# %%
pref_arr_geom.plot()

# %%
# ?drop
# Out:
# Object `drop` not found.
